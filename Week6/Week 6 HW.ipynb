# %%
import pandas   #匯入pandas模組
import random   #匯入random模組
import requests #匯入requests模組
import json     #匯入json模組
from bs4 import BeautifulSoup#匯入BeautifulSoup模組
import tkinter #匯入tkinter模組

scenery={1:'象山',2:'淡水',3:'九份',4:'烘爐地',5:'大直美麗華',6:'饒河夜市',7:'彩虹橋',8:'大湖公園',9:'士林夜市',
         10:'台北101',11:'西門町',12:'公館商圈',13:'貓空',14:'動物園',15:'台北車站',16:'南機場夜市',
         17:'飛機巷',18:'松山文創園區',19:'剝皮寮',20:'市政府'}
game={1:'荒野亂鬥',2:'極速領域',3:'Garena傳說對決',4:'旅行青蛙',5:'Free Fire-我要活下去',6:'第五人格-1v4懸疑競技手遊',7:'天堂M',
      8:'球跳塔',9:'決戰!平安京',10:'Happy Glass',11:'囧囧挑戰2',12:'神魔之塔',13:'狙擊3D刺客-我要活下去',
      14:'楓之谷M',15:'糖果傳奇',16:'麻將明星3缺1',17:'黑色沙漠MOBILE',18:'LOVE Balls',19:'神來也麻將',20:'叫我萬歲爺'}
movie={1:'X戰警:黑鳳凰\n簡介:X戰警們將面對有史以來最強勁的\
對手—而那個人，竟是他們自己的隊員。在一次外太空救援事件中，琴遭受了\
宇宙間一股神秘且猛烈的力量所攻擊，傷勢嚴重讓她也差\
點賠上了自己的性命。然而，當她返回家中時，她卻發現這股神秘之力竟將她\
體內的力量以驚人的倍數無限擴大，甚至遠遠超過了自己所能控制的範圍。在她\
努力與之對抗，並試圖發揮所能時，她卻漸漸發現自己既無法理解更沒有方法去\
內化體內無限膨脹的超然力量。\n隨著琴逐漸地失控，並開始傷害她身邊親近且\
親愛的人們時，她開始複雜化甚至是離間所有X戰警們之間最初、最緊密的連結\
與組織。隨著團隊的分崩離析，X戰警們將試圖要重新找回另自己團結一心的方式\
——而這不僅僅是為了修補琴內心破碎的靈魂，更是要拯救我們唯一的星球，免於\
外星生物利用琴做為武力來不法統治整個銀河系。',2:'阿拉丁\n簡介:擦亮神燈 小心翼翼許下三個願望...\n\
在沙漠中心的古老城市裡，藏著神祕的傳說，只要獲得帶有魔法的神燈，\
法力無邊的精靈就會實現你的三個願望。機智的窮小子阿拉丁，遇上了勇敢獨立的\
茉莉公主，對抗邪惡巫師賈方，阻止他密謀叛變奪取國王寶座，藉由幽默調皮的神\
燈精靈出手相助，譜出一段浪漫的愛情故事。《阿拉丁》真人版電影音樂將由\
曾獲8座奧斯卡金像獎的配樂大樂艾倫孟肯擔任配樂，當中包括曾獲奧斯卡最佳\
原創歌曲的《A Whole New World》，更有全新創作的兩首歌曲。',3:'哥吉拉II怪獸之王\n簡介:\
秘密行動單位：「君主組織」尋找的多頭泰坦級的怪獸，都將出現在電影中，\
在人類的城市裡無情地肆虐。電影預告由米莉芭比布朗飾演的麥蒂森羅素試圖\
透過無線電聯絡生還者做開端，但是在多頭巨獸的瘋狂肆虐下，無線電的另一頭\
只傳來更多的災情，許多城市似乎已經被破壞殆盡，專家們相信這些巨大的怪獸\
只是冰山一角，怪獸們早已遍佈世界各地，隨時準備爭奪霸權，而「君主組織」\
芹澤博士(渡邊謙 飾)甚至提出：我們才是哥吉拉的寵物。究竟哪幾頭怪獸會保護人\
的一大把豌豆，因為思念起老伴作的豌豆炊飯，在小玉喵的幫(搗)助(蛋)\
之下，大吉靠著老伴親筆寫的一本食譜完成了這道料理，大吉一邊吃著\
美食，一邊感慨這份食譜只寫了幾頁。「既然爺爺手藝這麼好，何不由\
爺爺來完成這本食譜呢？」在咖啡廳女主人的鼓勵之下，大吉爺爺開始\
一頁一頁地親筆填滿這本食譜。可是，身體向來硬朗的爺爺卻不敵病魔\
來襲，突然倒下了……',14:'詐騙女神\n簡介:敘述瑞貝爾威爾森和安海\
瑟薇是一對擦出精彩火花的女騙徒，她們在位於南法的一座濱海小鎮\
展開一場騙術大比拼。喬瑟芬柴斯特菲德（安海瑟薇 飾）是一個穿著\
光鮮亮麗、蠱惑誘人、善於算計、刁滑奸詐的英國正妹，她在濱海博\
蒙這座位於南法蔚藍海岸的小鎮擁有一棟豪宅，專門詐騙來自世界各\
地的有錢凱子。潘妮賴斯特（瑞貝爾威爾森 飾）則是一個無憂無慮、\
愛玩愛鬧的澳洲胖妞，專門在酒吧夜店靠著網路照騙，騙走好色男人\
的大把鈔票；喬瑟芬則是專門在高級賭場裝成傻妞，騙走好色老男人\
價值不斐的鑽石項鍊或戒指。沒想到有一天潘妮突然闖入喬瑟芬經營\
得有聲有色的詐騙世界，而且想要跟她搶地盤。雖然她們使用的詐騙\
手法大有不同，但是她們都是專門把男人騙得團團轉的詐騙女神。瑞\
貝爾威爾森擅於表演肢體喜劇，安海瑟薇則是冰雪聰明、擅於花言巧\
語，這對詐騙女神為了爭取地盤立下賭約，她們必須用盡絕招、不計\
代價騙取一名天真的科技業億萬富翁（艾力克斯夏普 飾）的感情和金錢。',\
15:'艾莉塔:戰鬥天使\n簡介:是部充滿著希望、愛情及權利鬥爭的超級\
動作鉅作，劇情設定在未來的幾個世紀後，描述一個名叫「艾莉塔」\
（羅莎薩拉查 飾）並且完全喪失記憶的機械合成人，她被充滿熱心的\
合成人醫師依德（克里斯多夫華茲 飾）在廢鐵鎮一處的廢料場裡拯救\
出來，並將她從受損的狀態中修護重建；甦醒過來的她，發掘所有的\
事物對她來說都是全新體驗，正當她開始重新適應這個險惡的廢鐵鎮\
新生活同時，依德也試著避開讓艾莉塔尋回她神秘的過去，但她的鎮\
上好友雨果（基安強生 飾）卻起身幫助艾莉塔恢復過往記憶，同時也\
讓兩人的感情急速加溫，直到致命的威脅到來，危急著她所培養出來\
的全新感情，這才喚醒了她擁有保護朋友、家人及她的真愛的強大戰\
鬥功力，這一切更將引導著艾莉塔揭開社會的真相，並對抗黑暗且腐\
敗世界的不公不義，最後更發現一個少女也可以有改變她所存在世界\
的力量。',16:'驚奇隊長\n簡介:《復仇者聯盟：無限之戰》中，當薩\
諾斯彈指的灰飛煙滅後，神盾局局長呼叫器中出現的標誌正是驚奇\
隊長-卡蘿丹佛斯的徽章標誌，而這次的故事將帶我們認識這位漫威\
最強女英雄。\n故事的背景在1990年代，講述當時地球陷入兩個外\
星世界的宇宙之戰，女飛官卡蘿丹佛斯如何成為漫威宇宙最強的女\
英雄- 驚奇隊長。這也是漫威電影宇宙中，首部女英雄的獨立電影。',\
17:'一個巨星的誕生\n簡介:在《一個巨星的誕生》中，布萊德利\
庫柏與女神卡卡挾著強大的演技及歌藝攜手合作，來演繹出主人\
翁傑克與艾莉這一對才華洋溢的藝術家，在舞台上及人生中的結\
合，及兩人間狂野和熾熱的愛情故事。他倆複雜糾結的戀情充滿\
動人曲折，從開始的美麗承諾到後期的心痛崩裂，雖遭遇挫折兩\
人仍努力挽回…',18:'猛毒\n簡介:自《蜘蛛人3》出現就備受關注的\
最強宿敵「猛毒」身為外星有機生命體，需尋找宿主結合才能生\
存，能賦予宿主超越想像的強大能量，亦正亦邪的角色特質更讓\
「猛毒」成為漫威漫畫裡最受歡迎的角色之一。',19:'水行俠\n簡介:\
傑森摩莫亞領銜主演片名角色，會帶領觀眾跨越七個海底王國中\
浩瀚、視覺上令人屏息的水中世界。這部電影將揭露半人類、半\
亞特蘭提斯人亞瑟庫瑞（Arthur Curry傑森摩莫亞 飾） 的起源\
故事，跟隨他踏上他畢生的旅程，這不只會迫使他面對自己的出\
身，也會讓他發現自己有沒有資格登上他與生俱來的……國王寶\
座。',20:'懸案密碼:第64號\n簡介:一份病歷串起五段看似不相干\
的人生、 數十年前醜惡不公的醫療行徑，以及隱藏在幸福國度\
背後，眾人不願言說的真相......\n\n兩名工人在一棟老舊的哥本\
哈根公寓有驚人的發現：一道假牆後面竟然藏著三具像木乃伊般\
乾癟的屍體，圍著餐桌坐著只留一個空位。案子很快就落到Q部\
門調查總長卡爾莫克及助理阿薩德的桌上，得靠他們去查出這三\
具屍體的身份還有第四個位置是要留給誰的。\n\n卡爾與阿薩德終\
於找到公寓的承租人的線索，是指向史葡格島上一間惡名昭彰、\
專門收容行為偏差女孩的機構。此機構實施非人道的監視與折磨\
，多重駭人的實驗至今仍然進行，因此卡爾和阿薩德必須與時間\
競賽，在下一起謀殺及攻擊出現前阻止一切。\n丹麥最神祕離奇\
、卻又無人能破的懸案，誰能解開通往關鍵線索的密碼…？！'}
series={1:'美劇: How I Met Your Mother\n簡介: 情境喜劇，故事是關於主角泰德·莫斯比在2030年時開始向他的孩子述說他如何與他們的媽媽相遇的過程',
        2:'美劇: Friends\n簡介: 是一部由美國NBC拍攝的展示紐約曼哈頓三男三女六位好友日常生活的情景喜劇',
        3:'美劇: The Big Bang Theory\n簡介: 四位主角是高智商的書呆子，住在他們對門的是一位漂亮的金髮美女佩妮，四個主角的書呆子氣與佩妮的社交能力形成了鮮明的對比，讓全劇充滿了喜劇色彩',
        4:'美劇: Brooklyn Nine-Nine\n簡介: 劇集背景設定在紐約市警察局旗下位於布魯克林區的虛構警區99分局，講述分局裡的警探和新上任的總警司之間所發生的爆笑趣事。',
        5:'美劇: Breaking Bad \n簡介: 講述高中化學教師華特·懷特（Walter White）的犯罪故事。他患上了末期肺癌，加上事業不如意，在化學的天份才能無法發揮之下而人生陷入低谷，絕望的他協同曾受教於他的傑西·平克曼（Jesse Pinkman）製作及販賣冰毒，希望自己製毒賺來的錢能在他死後解決家中迫切的財務危機。',
        6:'美劇: House of Cards\n簡介: 本劇背景設置在現今的華盛頓哥倫比亞特區，講述了眾議院南卡羅來納州第五國會選區民主黨籍議員、多數黨黨鞭弗蘭克·安德伍在晉升為國務卿的希望破滅後，在妻子克萊爾的幫助下，開始運用複雜的權術獲得最高權力的故事。劇集主要涉及的主題是無情的實用主義，操縱和權力。',
        18:'韓劇:《ITEM》\n簡介: 此劇講述命運交錯的首爾地方檢察官與廣域調查隊犯罪側寫師，在偵辦連續殺人案的過程當中，經歷與多項擁有特殊能力物品有關的離奇事件，從中逐步揭露其背後陰謀，並持續與幕後黑手展開正邪對決的故事。',
        19:'韓劇:《耀眼》\n簡介: 此劇是一部穿越時間的奇幻感人倫理劇，描述一個還沒將自己有限生命都過上一遍、因救爸爸而丟失自己的全部時光的少女和一個因在不幸的家庭中長大，遭遇連連的打擊，對人生絕望的青年人的故事。',
        20:'韓劇:《Sky Castle》 \n簡介: 此劇講述韓國上流社會的「SKY Castle」中，一群欲扶助丈夫事業和培育子女成為二代貴族的貴婦故事。',
        21:'韓劇:《你也是人類嗎》 \n簡介: 此劇以AI人工智慧為題材，講述因一場意外而陷入昏迷的富三代「南信」，身為科學家的母親製造出了一個智能機器人「南信 III」來代替他，也因此捲入了財閥家族的權力爭鬥故事。',
        22:'韓劇:《謎霧》 \n簡介: 此劇講述被認為是殺人事件嫌疑人的韓國頂尖主播高惠蘭（金南珠飾）和她的律師丈夫姜泰旭（池珍熙飾）所相信的愛情的真諦的激情懸疑故事。',
        23:'陸劇:《三生三世十里桃花》\n簡介:  翼君擎蒼向天族挑起戰爭，天族付出慘痛代價墨淵封印了擎蒼，同年金蓮託生的天孫夜華出世。七萬年後擎蒼將破出封印，青丘狐帝么女白淺再次將擎蒼封印，因此被其封去法力、記憶和容貌，落入凡塵與夜華相識、相戀，後被帶入天宮。',
        24:'陸劇:《皓鑭傳》\n簡介: 《皓鑭傳》一劇以戰國晚期為背景，故事圍繞秦趙兩國鬥爭而展開。趙國御史之女李皓鑭（吳謹言 飾）因家族鬥爭被迫為奴，被商人呂不韋（聶遠 飾）買下。後來與當時的秦國質子嬴異人（茅子俊 飾）幾經波折，發生感情。李皓鑭積極尋求改變命運、呂不韋一心想成為人中之王、嬴異人迫切需要返回秦國，三人為不同目的而結盟，聯手在戰國歷史洪流中追求各自理想。',
        25:'陸劇:《築夢情缘》\n簡介: 二十世紀二十年代初，亂世中少年沈其南一家忽遭飛來橫禍。父母蒙難，兄妹四人歷經艱險逃到上海卻不幸離散。在絕望中經歷層層考驗的沈其南與富家大小姐建築設計師傅函君青梅竹馬長大。長大后，沈其南和傅函君懷揣著民族夢想，堅守「以人為本」的設計理念，將中華優秀傳統文化精髓運用到建築設計和建造領域，並逐漸在建築界得到認可。'}
def congratulation_name(name):      #當選擇喜歡時會恭喜詞
    c="-"*30+"\n《祝你有個美好的"+name+"的時光》\n"+"-"*30
    return c
def append_function(choice,lists):  #將使用者喜歡的內容放進一個串列，最後可以印出喜愛清單
    aa=choice+":"+lists
    like_list.append(aa)    
def scenery_choice():       #地點選擇
    global a
    while 1:
        a=random.randint(1,20)
        print("為您推薦的地點為:"+scenery[a])
        result=input("請問是否喜歡這個景點？「喜歡」請輸入1，「不喜歡」請輸入2：")
        if result=="2":
            continue
        if result=="1":
            append_function("地點",scenery[a])
            a=congratulation_name("旅行")
            return a
        else:
            while result=="1"or "2":
                print("請輸入正確的回應！")
                result=input("請問是否喜歡這個景點？「喜歡」請輸入1，「不喜歡」請輸入2：")
                if result=="1":
                    append_function("地點",scenery[a])
                    a=congratulation_name("旅行")
                    return a
                if result=="2":
                    break
def game_choice():
    global a
    while 1:
        a=random.randint(1,20)
        print("為您推薦的遊戲為:"+game[a])
        result=input("請問是否喜歡這個遊戲？「喜歡」請輸入1，「不喜歡」請輸入2：")
        if result=="2":
            continue
        if result=="1":
            append_function("遊戲",game[a])
            a=congratulation_name("遊戲")
            return a
        else:
            while result=="1"or "2":
                print("請輸入正確的回應！")
                result=input("請問是否喜歡這個遊戲？「喜歡」請輸入1，「不喜歡」請輸入2：")
                if result=="1":
                    append_function("遊戲",game[a])
                    a=congratulation_name("遊戲")
                    return a
                if result=="2":
                    break
def song_choice():
    dfs = pandas.read_html("https://tw-pop-chart.blogspot.com/2019/06/kkbox-2019-06-07-2019-06-13.html") #讀取網頁的表單
    music=dfs[0] #取出表單的第一個元素
    while 1:
        a=random.randint(0,49)
        singer=music.loc[a][2]  #取得隨機變數a對應的歌曲
        name=music.loc[a][3] #取得隨機變數a對應的歌曲
        print("為您推薦的歌曲為:"+singer+name)
        global b
        result=input("請問是否喜歡這首歌？「喜歡」請輸入1，「不喜歡」請輸入2：")
        if result=="2":
            continue
        if result=="1":
            append_function("歌曲",singer+name)
            b=congratulation_name("聽歌")
            return b
        else:
            while result=="1"or "2":
                print("請輸入正確的回應！")
                result=input("請問是否喜歡這首歌？「喜歡」請輸入1，「不喜歡」請輸入2：")
                if result=="1":
                    append_function("歌曲",singer+name)
                    b=congratulation_name("聽歌")
                    return b
                if result=="2":
                    break
def book_choice():
    # 下載博客來暢銷排行榜內容
    r = requests.get('https://www.books.com.tw/web/sys_tdrntb/books/?loc=subject_005')

    # 開啟檔案
    fp = open("bookstest.txt", "a",encoding='utf-8')
    # 確認是否下載成功
    if r.status_code == requests.codes.ok:
      # 以 BeautifulSoup 解析 HTML 程式碼
      soup = BeautifulSoup(r.text, 'html.parser')

      # 以 CSS 的 class 抓出各類頭條新聞
      stories = soup.select('div.type02_bd-a > h4')
      #stories = soup.find_all('div.type02_bd-a>h4')
    while 1:
        a=random.randint(1,100)
        print("為您推薦暢銷排行榜第",a,"名-",stories[a].text,sep="")
        global b
        result=input("請問是否喜歡這本書？「喜歡」請輸入1，「不喜歡」請輸入2：")
        if result=="2":
            continue
        if result=="1":
            append_function("書籍",stories[a].text)
            b=congratulation_name("看書")
            return b
        else:
            while result=="1"or "2":
                print("請輸入正確的回應！")
                result=input("請問是否喜歡本書？「喜歡」請輸入1，「不喜歡」請輸入2：")
                if result=="1":
                    append_function("書籍",stories[a].text)
                    b=congratulation_name("看書")
                    return b
                if result=="2":
                    break


def delete_likelist(list):
    global resultList
    resultList=[]
    for item in list:
        if not item in resultList:
            resultList.append(item)
    return resultList
def movie_like():
        win.destroy()
        global a
        a=True
        movie_name=movie[c].split("\n")
        append_function("電影",movie_name[0])
        print(congratulation_name("電影"))
        return a
def series_like():
        win.destroy()
        global a
        a=True
        series_name=series[c].split("\n")
        append_function("影集",series_name[0])
        print(congratulation_name("影集"))
        return a
def dislike():

        win.destroy()
        global a
        a=False
        return a

print("我是Spike！我好無聊!請幫我安排空閒時間要做甚麼？")
"""time=input("請問您有多少空閒時間(分鐘):")"""
choice_limit=["0","1","2","3","4","5","6"]
choice="7"
like_list=[]
while choice!="0":
    choice=input("【Spike對以下哪種活動有興趣呢?】\n(1)出門\n(2)遊戲\n(3)看書\n(4)聽歌\n(5)電影\n(6)影集\n△小提醒欲結束請輸入0\n您選擇的是:")
    print("-"*30)
    if choice in choice_limit:
        if choice=="1":
            scenery_choice()
            print(a)
            continue
        if choice=="2":
            game_choice()
            print(a)
            continue
        if choice=="3":
            book_choice()
            print(b)
            continue
        if choice=="4":
            song_choice()
            print(b)
            continue
        if choice=="5":
            while 1:
                    a=None
                    win=tkinter.Tk()
                    win.title("好看的電影")
                    win.geometry("500x300+300+0")
                    c=random.randint(1,20)
                    lab2=tkinter.Label(win, text="推薦的電影:"+movie[c],width = 450,wraplength = 450,justify = 'left')
                    btn1=tkinter.Button(win, text="喜歡!" ,command=movie_like, bg="blue")
                    btn2=tkinter.Button(win, text="不喜歡!",command=dislike, bg="yellow")
                    lab2.pack(anchor="nw")
                    btn1.pack(anchor="s")
                    btn2.pack(anchor="s")
                    win.mainloop()
                    if a==True:
                        break
                    if a==False:
                        continue
                    if a!=True or a!=False:
                        break                            
        if choice=="6":
            while 1:
                    a=None
                    win=tkinter.Tk()
                    win.title("好看的影集")
                    win.geometry("500x300+300+0")
                    c=random.randint(1,20)
                    lab2=tkinter.Label(win, text="推薦的影集:"+series[c],width = 450,wraplength = 450,justify = 'left')
                    btn1=tkinter.Button(win, text="喜歡!" ,command=series_like, bg="blue")
                    btn2=tkinter.Button(win, text="不喜歡!",command=dislike, bg="yellow")
                    lab2.pack(anchor="nw")
                    btn1.pack(anchor="s")
                    btn2.pack(anchor="s")
                    win.mainloop()
                    if a==True:
                        break
                    if a==False:
                        continue
                    if a!=True or a!=False:
                        break                    
    else:
        print("請輸入正確回應！")
delete_likelist(like_list)
print("謝謝您的使用!妳的喜愛清單如下:\n","\n".join(resultList),sep="")
# Out:
# 我是Spike！我好無聊!請幫我安排空閒時間要做甚麼？
# 【Spike對以下哪種活動有興趣呢?】
# (1)出門
# (2)遊戲
# (3)看書
# (4)聽歌
# (5)電影
# (6)影集
# △小提醒欲結束請輸入0
# 您選擇的是:2
# ------------------------------
# 為您推薦的遊戲為:神來也麻將
# 請問是否喜歡這個遊戲？「喜歡」請輸入1，「不喜歡」請輸入2：2
# 為您推薦的遊戲為:囧囧挑戰2
# 請問是否喜歡這個遊戲？「喜歡」請輸入1，「不喜歡」請輸入2：2
# 為您推薦的遊戲為:旅行青蛙
# 請問是否喜歡這個遊戲？「喜歡」請輸入1，「不喜歡」請輸入2：1
# ------------------------------
# 《祝你有個美好的遊戲的時光》
# ------------------------------
# 【Spike對以下哪種活動有興趣呢?】
# (1)出門
# (2)遊戲
# (3)看書
# (4)聽歌
# (5)電影
# (6)影集
# △小提醒欲結束請輸入0
# 您選擇的是:5
# ------------------------------
# ------------------------------
# 《祝你有個美好的電影的時光》
# ------------------------------
# 【Spike對以下哪種活動有興趣呢?】
# (1)出門
# (2)遊戲
# (3)看書
# (4)聽歌
# (5)電影
# (6)影集
# △小提醒欲結束請輸入0
# 您選擇的是:6
# ------------------------------
